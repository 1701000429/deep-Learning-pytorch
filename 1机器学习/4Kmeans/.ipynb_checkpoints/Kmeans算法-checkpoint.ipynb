# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('./dataset/testSet.txt',sep='\t',names=['X','Y'])
print(data.head())
data=np.array(data)
print(data.shape)
# Out:
#         X       Y
# 0  2.7266  3.0102
# 1  3.1304  2.4673
# 2  3.0492  2.5250
# 3  3.2260  3.1649
# 4  2.7223  2.5713
# (400, 2)

# %% [markdown]
# # Kmeans 算法步骤
# ## 1.选择初始化的 k 个样本作为初始聚类中心 ；
# ## 2.针对数据集中每个样本 计算它到 k 个聚类中心的距离并将其分到距离最小的聚类中心所对应的类中；
# ## 3.针对每个类别  ，重新计算它的聚类中心
# ## 4.重复上面 2 3 两步操作，直到达到某个中止条件（迭代次数、最小误差变化等）。

# %%
#定义距离算法
def distance(sample,dataset):
    "输入矩阵（1行n列，m行n列），输出shape（m,）"
    #print("利用广播机制，计算sample1到dataset全部的距离")
    data=np.sum((dataset-sample)**2,axis=1)
    data=np.sqrt(np.float32(data))
    return data
#定义聚簇中心算法
def center(dataset):
    "输入shape(x,2)，输出shape(1,2)"
    Xmin=dataset[:,0]
    Ymin=dataset[:,1]
    return np.array([np.mean(Xmin),np.mean(Ymin)])
def MyKMeans(data:np.array,
            k=4,
            max_iter=1000):

    #1.选取随机中心k个,矩阵rand_center.shape=(k,2)
    rand_center=np.array([data[0]]) 
    for i in range(k-1):
        center1=np.random.randint(int(len(data)*(i+1)/k),int(len(data)*(i+2)/k))
        print(center1)
        rand_center=np.r_[rand_center,[data[center1]]]
    print("第一轮随机中心坐标取值:\n",rand_center)
    
    #计算距离，并重新计算中心
    for i in range(max_iter):
        #2. 计算距离MyDistance.shape=(len(data),k)
        MyDistance=distance(rand_center[0],data)
        for j in range(k-1):
            MyDistance=np.c_[MyDistance,distance(rand_center[j+1],data)]
        #print("距离矩阵:\n",MyDistance)  #每一行表示到各个clus的距离
        argDistance=np.argmin(MyDistance, axis=1) #到哪个簇最短
        y_kmean=np.array(argDistance)

        #3. 重新计算k个聚簇中心
        filterArray =(y_kmean ==0)
        rand_center=np.array([center(data[filterArray])])


        for counter in range(k-1):
            filterArray =(y_kmean ==(counter+1))
            rand_center= np.r_[rand_center,[center(data[filterArray])]]
        print("重新计算后，第"+str(i)+"轮中心坐标：\n",rand_center)
        
        
        
        
    centroids= rand_center
    
    return centroids,y_kmean

# %%
centroids,y_kmean=MyKMeans(data)
# Out:
# 114
# 242
# 388
# 第一轮随机中心坐标取值:
#  [[2.7266 3.0102]
#  [2.5973 2.8949]
#  [8.0147 8.0012]
#  [6.8945 5.2523]]
# 重新计算后，第0轮中心坐标：
#  [[3.0889732  4.14435752]
#  [2.61937143 2.63741224]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第1轮中心坐标：
#  [[3.06923059 5.10513412]
#  [2.9066453  2.81524359]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第2轮中心坐标：
#  [[3.03446607 5.91268214]
#  [2.95227397 2.96034041]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第3轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第4轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第5轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第6轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第7轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第8轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第9轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第10轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第11轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第12轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第13轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第14轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第15轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第16轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第17轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第18轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第19轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第20轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第21轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第22轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第23轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第24轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第25轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第26轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，
�中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第399轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第400轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第401轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第402轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第403轮中心坐标：
#  [[3.02211698 6.00770189]
# ...
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第866轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第867轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第868轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第869轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第870轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第871轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第872轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第873轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第874轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第875轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第876轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第877轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第878轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第879轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第880轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第881轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第882轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第883轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第884轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第885轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第886轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第887轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第888轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第889轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第890轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第891轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第892轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第893轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第894轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第895轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第896轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第897轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第898轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第899轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第900轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第901轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第902轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第903轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第904轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第905轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第906轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第907轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第908轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第909轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第910轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第911轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第912轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第913轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第914轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第915轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第916轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第917轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第918轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第919轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第920轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第921轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第922轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第923轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第924轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第925轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第926轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第927轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第928轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第929轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第930轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第931轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第932轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第933轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第934轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第935轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第936轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第937轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第938轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第939轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第940轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第941轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第942轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第943轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第944轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第945轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第946轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第947轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第948轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第949轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第950轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第951轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第952轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第953轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第954轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第955轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第956轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第957轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第958轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第959轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第960轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第961轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第962轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第963轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第964轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第965轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第966轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第967轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第968轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第969轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第970轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第971轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第972轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第973轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第974轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第975轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第976轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第977轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第978轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第979轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第980轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第981轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第982轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第983轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第984轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第985轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第986轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第987轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第988轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第989轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第990轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第991轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第992轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第993轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第994轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第995轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第996轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第997轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第998轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]
# 重新计算后，第999轮中心坐标：
#  [[3.02211698 6.00770189]
#  [2.95832148 2.98598456]
#  [8.08169456 7.97506735]
#  [6.99438039 5.05456275]]

# %%
# 呈现未归集前的数据
plt.scatter(data[:, 0], data[:, 1], s=50)
plt.yticks(())
plt.show()
# 呈现分类后的数据
plt.scatter(data[:, 0], data[:, 1], c=y_kmean, s=50, cmap='viridis')
plt.scatter(centroids[:, 0], centroids[:, 1], c='black', s=100, alpha=0.5)
plt.show()

# %%
#调库方式实现Kmeans
#1.指定K
k=4

# 2. 模型构建
km = KMeans(n_clusters=k, init='k-means++', max_iter=30)
km.fit(data)

# 获取簇心
centroids = km.cluster_centers_
# 获取归集后的样本所属簇对应值
y_kmean = km.predict(data)

# %%
# 呈现未归集前的数据
plt.scatter(data[:, 0], data[:, 1], s=50)
plt.yticks(())
plt.show()

plt.scatter(data[:, 0], data[:, 1], c=y_kmean, s=50, cmap='viridis')
plt.scatter(centroids[:, 0], centroids[:, 1], c='black', s=100, alpha=0.5)
plt.show()

# %%
#numpy数组过滤总结
print("2维数组示例============================================")
data = np.array([[20,35],[20,20],[1,20]])
print(data.shape)
y_mean=np.array([0,1,1])
print(y_mean.shape)
filterArray =(y_mean ==1)
print(equal_to_ten_and_five)
print( data[filterArray])

print("3维数组示例============================================")
data = np.random.randint(0,3,size=(2,3,4))
print(data)
print(data.shape)
y_mean=np.array([0,1])
print(y_mean.shape)
filterArray =(y_mean ==1)
print(filterArray)
print( data[filterArray])
# Out:
# 2维数组示例============================================
# (3, 2)
# (3,)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-a5a6f4dcaeef> in <module>
#       6 print(y_mean.shape)
#       7 filterArray =(y_mean ==1)
# ----> 8 print(equal_to_ten_and_five)
#       9 print( data[filterArray])
#      10
#
# NameError: name 'equal_to_ten_and_five' is not defined
